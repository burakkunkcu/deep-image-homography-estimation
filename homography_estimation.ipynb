# %% [markdown]
# ## Mount GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Parameters

# %%
# Dataset
dataset_folder_path = '/content/gdrive/MyDrive/deephomography/dataset/'
rho = 32
patch_size = 128
image_size = (320,240)

# Dataloader
batch_size = 64
dataset_mean = 113.55

# Training
num_iterations = 90000
checkpoint_path = '/content/gdrive/MyDrive/deephomography/models/checkpoint.pth'

# Create required folder(s)
# !mkdir -p $(dirname {checkpoint_path})

# %% [markdown]
# ## Extract dataset

# %%
# !echo "Extracting train2014homography.tar..."
# !tar -xf {dataset_folder_path}/train2014homography.tar

# !echo "Extracting val2014homography.tar..."
# !tar -xf {dataset_folder_path}/val2014homography.tar

# !echo "Extracting test2014homography.tar..."
# !tar -xf {dataset_folder_path}/test2014homography.tar
# Out:
# Extracting train2014homography.tar...
# Extracting val2014homography.tar...
# Extracting test2014homography.tar...

# %% [markdown]
# ## Homography Estimation with Deep Neural Networks

# %% [markdown]
# ### Custom PyTorch dataset & dataloader

# %%
import os
import numpy as np
import torch

class HomographyDataset(torch.utils.data.Dataset):
    def __init__(self, folder_path):
        self.folder_path = folder_path

        # List folder contents
        self.file_list = os.listdir(self.folder_path)

        # Set dataset size
        self.size = len(self.file_list)
    
    def __len__(self):
        return self.size

    def __getitem__(self, index):
        # Load sample
        patch, perturbed_patch, patch_points, perturbation = np.load(os.path.join(self.folder_path, self.file_list[index]), allow_pickle=True)

        # Normalisation
        patch = patch.astype(np.float32) - dataset_mean
        perturbed_patch = perturbed_patch.astype(np.float32) - dataset_mean
        perturbation = perturbation.astype(np.float32) / rho

        # Convert to PyTorch object
        patch = torch.unsqueeze(torch.from_numpy(patch), dim=0)
        perturbed_patch = torch.unsqueeze(torch.from_numpy(perturbed_patch), dim=0)
        perturbation = torch.flatten(torch.from_numpy(perturbation))

        # Stack two patches into a single tensor
        patch_pair = torch.concat((patch, perturbed_patch), dim=0)

        return patch_pair, perturbation

# Datasets
train_dataset = HomographyDataset(folder_path='train2014homography')
validation_dataset = HomographyDataset(folder_path='val2014homography')
test_dataset = HomographyDataset(folder_path='test2014homography')

# Number of processors
num_proc = len(os.sched_getaffinity(0))

# Dataloaders
train_dataloader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_proc)
validation_dataloader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=batch_size, shuffle=True, num_workers=num_proc)
test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=num_proc)

# %% [markdown]
# ### Network definition

# %%
class HomographyNet(torch.nn.Module):
    def __init__(self):
        super().__init__() # don't remove this line
        
        self.conv1 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=2, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU())
                                    
        self.conv2 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2))
        
        self.conv3 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU())
        
        self.conv4 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2))
        
        self.conv5 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU()) 
              
        self.conv6 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2))
        
        self.conv7 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU())
        
        self.conv8 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.5))
        
        self.fc1 = torch.nn.Sequential(
            torch.nn.Linear(in_features=128*16*16, out_features=1024),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.5))
        
        self.fc2 = torch.nn.Sequential(
            torch.nn.Linear(in_features=1024, out_features=8))

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.conv8(x)

        x = torch.flatten(x, 1)

        x = self.fc1(x)
        x = self.fc2(x)

        return x

homographynet = HomographyNet().to('cuda')

# %% [markdown]
# ### Test network shapes

# %%
import torchsummary

for dummy_input, dummy_label in train_dataloader:
    dummy_input, dummy_label = dummy_input.to('cuda'), dummy_label.to('cuda')

    dummy_output = homographynet(dummy_input)

    torchsummary.summary(homographynet, dummy_input.shape[1:])
    #print(homographynet)

    print(f'Dummy input shape: {dummy_input.shape}')
    print(f'Dummy label shape: {dummy_label.shape}')
    print(f'Dummy output shape: {dummy_output.shape}')
    print()

    if dummy_label.shape != dummy_output.shape:
        raise Exception("Shape mismatch for label and output!") 
    else:
        print("Label and output shapes are consistent.")

    break
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           1,216
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#             Conv2d-4         [-1, 64, 128, 128]          36,928
#        BatchNorm2d-5         [-1, 64, 128, 128]             128
#               ReLU-6         [-1, 64, 128, 128]               0
#          MaxPool2d-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,928
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#            Conv2d-11           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-12           [-1, 64, 64, 64]             128
#              ReLU-13           [-1, 64, 64, 64]               0
#         MaxPool2d-14           [-1, 64, 32, 32]               0
#            Conv2d-15          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-16          [-1, 128, 32, 32]             256
#              ReLU-17          [-1, 128, 32, 32]               0
#            Conv2d-18          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-19          [-1, 128, 32, 32]             256
#              ReLU-20          [-1, 128, 32, 32]               0
#         MaxPool2d-21          [-1, 128, 16, 16]               0
#            Conv2d-22          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#              ReLU-24          [-1, 128, 16, 16]               0
#            Conv2d-25          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-26          [-1, 128, 16, 16]             256
#              ReLU-27          [-1, 128, 16, 16]               0
#           Dropout-28          [-1, 128, 16, 16]               0
#            Linear-29                 [-1, 1024]      33,555,456
#              ReLU-30                 [-1, 1024]               0
#           Dropout-31                 [-1, 1024]               0
#            Linear-32                    [-1, 8]           8,200
# ================================================================
# Total params: 34,193,800
# Trainable params: 34,193,800
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 70.52
# Params size (MB): 130.44
# Estimated Total Size (MB): 201.09
# ----------------------------------------------------------------
# Dummy input shape: torch.Size([64, 2, 128, 128])
# Dummy label shape: torch.Size([64, 8])
# Dummy output shape: torch.Size([64, 8])
#
# Label and output shapes are consistent.

# %% [markdown]
# ### Optimizer and loss function

# %%
# Optimizer
homographynet_optim = torch.optim.SGD(homographynet.parameters(), lr=0.005, momentum=0.9)

# Loss function
homographynet_lossfn = torch.nn.MSELoss()

# %% [markdown]
# ### Validation/Test function

# %%
def average_corner_error(true, pred):
    true_scaled = rho * true.cpu().numpy()
    pred_scaled = rho * pred.cpu().numpy()

    squared_error = np.square(true_scaled - pred_scaled)

    batch_ace = (np.sqrt(squared_error[:,0] + squared_error[:,1]) + 
                 np.sqrt(squared_error[:,2] + squared_error[:,3]) + 
                 np.sqrt(squared_error[:,4] + squared_error[:,5]) + 
                 np.sqrt(squared_error[:,6] + squared_error[:,7])) / 4

    return np.mean(batch_ace, axis=0)

def test_model(model, dataloader, lossfn):
    # Set network to eval mode
    model.eval()

    # Initialise total loss and average corner error
    total_loss = 0
    total_ace = 0
    
    # Disable gradients inside this block
    with torch.no_grad():
        for patch_pair, H_fp in dataloader:
            # Move batch to GPU
            patch_pair, H_fp = patch_pair.cuda(), H_fp.cuda()

            # Run the network and obtain predicted homography 
            H_fp_pred = model(patch_pair)

            # Calculate loss
            total_loss += lossfn(H_fp, H_fp_pred)

            # Calculate average corner error
            total_ace += average_corner_error(H_fp, H_fp_pred)

    # Calculate mean loss
    mean_loss = total_loss / len(dataloader)

    # Calculate mean average corner error
    mean_ace = total_ace / len(dataloader)

    # Set network to train mode
    model.train()
    
    return mean_loss, mean_ace

# %% [markdown]
# ### Training

# %%
ep_start = 0
training_loss_list = []
validation_loss_list = []

# Calculate number of epochs
num_epochs = np.ceil(num_iterations / len(train_dataloader)).astype(int)

# Calculate number of reporting steps
num_report_steps = np.floor(len(train_dataloader) / 10)

# Calculate required digits for number of total epochs and iterations (for reporting)
epd = len(str(num_epochs))
itd = len(str(len(train_dataloader)))

# Check if a checkpoint exists
if os.path.isfile(checkpoint_path):
    # Load checkpoint
    print('Loading checkpoint...')
    checkpoint = torch.load(checkpoint_path)

    # Load variables from checkpoint
    ep_start = checkpoint['epoch']
    homographynet.load_state_dict(checkpoint['network_state'])
    homographynet_optim.load_state_dict(checkpoint['optim_state'])
    training_loss_list = checkpoint['tloss_list']
    validation_loss_list = checkpoint['vloss_list']

for ep in range(ep_start, num_epochs):
    # Initialise total loss
    total_loss = 0

    for it, (patch_pair, H_fp) in enumerate(train_dataloader):
        # Move batch to GPU
        patch_pair, H_fp = patch_pair.to("cuda"), H_fp.to("cuda")
        
        # Run the network and obtain predicted homography 
        H_fp_pred = homographynet(patch_pair)

        # Calculate loss
        loss = homographynet_lossfn(H_fp, H_fp_pred)
        total_loss += loss
        
        # Take an optimization step (clear the gradients first)
        homographynet_optim.zero_grad()
        loss.backward()
        homographynet_optim.step()
        
        if (it == 0 or (it + 1) % num_report_steps == 0):
            print(f'[Epoch: {(ep + 1):0{epd}d}/{num_epochs}, Iteration: {(it + 1):0{itd}d}/{len(train_dataloader)}] Iteration Loss (MSE): {loss:.6f}')
    
    # Calculate average training loss
    training_loss = total_loss / len(train_dataloader)
    training_loss_list.append(training_loss)

    # Try model on validation set and calculate 
    validation_loss, validation_ace = test_model(homographynet, validation_dataloader, homographynet_lossfn)
    validation_loss_list.append(validation_loss)

    print(f'[Epoch: {(ep + 1):0{epd}d}/{num_epochs}, Iteration: {(it + 1):0{itd}d}/{len(train_dataloader)}] Training Loss (MSE): {training_loss:.6f}, Validation Loss (MSE): {validation_loss:.6f}, Validation Corner Error (MACE): {validation_ace:.4f}')

    # Save checkpoint
    print('Saving checkpoint...')
    torch.save({'epoch': ep+1, 'network_state': homographynet.state_dict(), 'optim_state': homographynet_optim.state_dict(), 'tloss_list': training_loss_list, 'vloss_list': validation_loss_list}, checkpoint_path)
# Out:
# [Epoch: 01/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.464558
# [Epoch: 01/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.208769
# [Epoch: 01/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.152548
# [Epoch: 01/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.131850
# [Epoch: 01/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.121496
# [Epoch: 01/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.101339
# [Epoch: 01/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.077272
# [Epoch: 01/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.080910
# [Epoch: 01/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.086340
# [Epoch: 01/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.087685
# [Epoch: 01/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.080720
# [Epoch: 01/12, Iteration: 7813/7813] Training Loss (MSE): 0.130759, Validation Loss (MSE): 0.062111, Validation Corner Error (MACE): 9.4670
# Saving checkpoint...
# [Epoch: 02/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.083670
# [Epoch: 02/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.076409
# [Epoch: 02/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.072432
# [Epoch: 02/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.078527
# [Epoch: 02/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.090864
# [Epoch: 02/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.071567
# [Epoch: 02/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.062437
# [Epoch: 02/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.068470
# [Epoch: 02/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.069401
# [Epoch: 02/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.058057
# [Epoch: 02/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.047100
# [Epoch: 02/12, Iteration: 7813/7813] Training Loss (MSE): 0.070650, Validation Loss (MSE): 0.052973, Validation Corner Error (MACE): 8.6802
# Saving checkpoint...
# [Epoch: 03/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.054123
# [Epoch: 03/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.059500
# [Epoch: 03/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.053056
# [Epoch: 03/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.053002
# [Epoch: 03/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.051812
# [Epoch: 03/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.064834
# [Epoch: 03/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.053007
# [Epoch: 03/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.078353
# [Epoch: 03/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.052576
# [Epoch: 03/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.066371
# [Epoch: 03/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.059147
# [Epoch: 03/12, Iteration: 7813/7813] Training Loss (MSE): 0.059147, Validation Loss (MSE): 0.041492, Validation Corner Error (MACE): 7.5595
# Saving checkpoint...
# [Epoch: 04/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.050241
# [Epoch: 04/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.048113
# [Epoch: 04/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.051728
# [Epoch: 04/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.052714
# [Epoch: 04/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.050398
# [Epoch: 04/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.057727
# [Epoch: 04/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.050556
# [Epoch: 04/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.053868
# [Epoch: 04/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.047275
# [Epoch: 04/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.050432
# [Epoch: 04/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.054318
# [Epoch: 04/12, Iteration: 7813/7813] Training Loss (MSE): 0.052693, Validation Loss (MSE): 0.036550, Validation Corner Error (MACE): 7.1887
# Saving checkpoint...
# [Epoch: 05/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.046164
# [Epoch: 05/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.050690
# [Epoch: 05/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.046938
# [Epoch: 05/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.049025
# [Epoch: 05/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.051278
# [Epoch: 05/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.043924
# [Epoch: 05/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.052371
# [Epoch: 05/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.046084
# [Epoch: 05/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.061200
# [Epoch: 05/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.035086
# [Epoch: 05/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.041945
# [Epoch: 05/12, Iteration: 7813/7813] Training Loss (MSE): 0.048351, Validation Loss (MSE): 0.050198, Validation Corner Error (MACE): 8.4207
# Saving checkpoint...
# [Epoch: 06/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.044078
# [Epoch: 06/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.046351
# [Epoch: 06/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.045468
# [Epoch: 06/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.041364
# [Epoch: 06/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.044185
# [Epoch: 06/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.044024
# [Epoch: 06/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.059492
# [Epoch: 06/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.044835
# [Epoch: 06/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.042318
# [Epoch: 06/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.052824
# [Epoch: 06/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.046061
# [Epoch: 06/12, Iteration: 7813/7813] Training Loss (MSE): 0.044980, Validation Loss (MSE): 0.029708, Validation Corner Error (MACE): 6.3413
# Saving checkpoint...
# [Epoch: 07/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.044171
# [Epoch: 07/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.040982
# [Epoch: 07/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.041277
# [Epoch: 07/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.052638
# [Epoch: 07/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.048067
# [Epoch: 07/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.042488
# [Epoch: 07/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.038436
# [Epoch: 07/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.043910
# [Epoch: 07/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.035287
# [Epoch: 07/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.045806
# [Epoch: 07/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.036718
# [Epoch: 07/12, Iteration: 7813/7813] Training Loss (MSE): 0.042376, Validation Loss (MSE): 0.031557, Validation Corner Error (MACE): 6.4449
# Saving checkpoint...
# [Epoch: 08/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.042299
# [Epoch: 08/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.044943
# [Epoch: 08/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.036045
# [Epoch: 08/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.034692
# [Epoch: 08/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.038291
# [Epoch: 08/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.039119
# [Epoch: 08/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.047858
# [Epoch: 08/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.046525
# [Epoch: 08/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.042881
# [Epoch: 08/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.041198
# [Epoch: 08/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.034500
# [Epoch: 08/12, Iteration: 7813/7813] Training Loss (MSE): 0.040175, Validation Loss (MSE): 0.025437, Validation Corner Error (MACE): 5.8596
# Saving checkpoint...
# [Epoch: 09/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.036081
# [Epoch: 09/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.040451
# [Epoch: 09/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.040389
# [Epoch: 09/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.046174
# [Epoch: 09/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.038138
# [Epoch: 09/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.034621
# [Epoch: 09/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.034138
# [Epoch: 09/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.036448
# [Epoch: 09/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.035657
# [Epoch: 09/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.035624
# [Epoch: 09/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.042714
# [Epoch: 09/12, Iteration: 7813/7813] Training Loss (MSE): 0.038263, Validation Loss (MSE): 0.025017, Validation Corner Error (MACE): 5.8060
# Saving checkpoint...
# [Epoch: 10/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.034764
# [Epoch: 10/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.033847
# [Epoch: 10/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.036682
# [Epoch: 10/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.033741
# [Epoch: 10/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.039922
# [Epoch: 10/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.039471
# [Epoch: 10/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.036580
# [Epoch: 10/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.033193
# [Epoch: 10/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.034966
# [Epoch: 10/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.032029
# [Epoch: 10/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.031359
# [Epoch: 10/12, Iteration: 7813/7813] Training Loss (MSE): 0.036535, Validation Loss (MSE): 0.021747, Validation Corner Error (MACE): 5.3939
# Saving checkpoint...
# [Epoch: 11/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.036510
# [Epoch: 11/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.036949
# [Epoch: 11/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.031054
# [Epoch: 11/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.034330
# [Epoch: 11/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.030294
# [Epoch: 11/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.034132
# [Epoch: 11/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.039435
# [Epoch: 11/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.033457
# [Epoch: 11/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.033191
# [Epoch: 11/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.038235
# [Epoch: 11/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.041136
# [Epoch: 11/12, Iteration: 7813/7813] Training Loss (MSE): 0.035216, Validation Loss (MSE): 0.025842, Validation Corner Error (MACE): 5.8476
# Saving checkpoint...
# [Epoch: 12/12, Iteration: 0001/7813] Iteration Loss (MSE): 0.031688
# [Epoch: 12/12, Iteration: 0781/7813] Iteration Loss (MSE): 0.033688
# [Epoch: 12/12, Iteration: 1562/7813] Iteration Loss (MSE): 0.026857
# [Epoch: 12/12, Iteration: 2343/7813] Iteration Loss (MSE): 0.035565
# [Epoch: 12/12, Iteration: 3124/7813] Iteration Loss (MSE): 0.031918
# [Epoch: 12/12, Iteration: 3905/7813] Iteration Loss (MSE): 0.035471
# [Epoch: 12/12, Iteration: 4686/7813] Iteration Loss (MSE): 0.029943
# [Epoch: 12/12, Iteration: 5467/7813] Iteration Loss (MSE): 0.029333
# [Epoch: 12/12, Iteration: 6248/7813] Iteration Loss (MSE): 0.033024
# [Epoch: 12/12, Iteration: 7029/7813] Iteration Loss (MSE): 0.038119
# [Epoch: 12/12, Iteration: 7810/7813] Iteration Loss (MSE): 0.029752
# [Epoch: 12/12, Iteration: 7813/7813] Training Loss (MSE): 0.033852, Validation Loss (MSE): 0.022906, Validation Corner Error (MACE): 5.4791
# Saving checkpoint...

# %% [markdown]
# ### Testing

# %%
import matplotlib.pyplot as plt

# Load checkpoint from file
checkpoint = torch.load(checkpoint_path)

# Load variables from checkpoint
ep_start = checkpoint['epoch']
homographynet.load_state_dict(checkpoint['network_state'])
training_loss_list_cuda = checkpoint['tloss_list']
validation_loss_list_cuda = checkpoint['vloss_list']

# Move losses to CPU and convert to Numpy
training_loss_list = [i.cpu().detach().numpy() for i in training_loss_list_cuda]
validation_loss_list = [i.cpu().detach().numpy() for i in validation_loss_list_cuda]

# Plot learning curve
plt.figure()
plt.title('Training & Validation Losses')
plt.xlabel('epoch')
plt.ylabel('mse')
plt.plot(training_loss_list, 'b', validation_loss_list, 'r')
plt.legend(['training','validation'])
plt.show()

# Print minimum training and validation losses
print()
print(f'Minimum training loss (MSE): {min(training_loss_list):.8f}')
print(f'Minimum validation loss (MSE): {min(validation_loss_list):.8f}')
print()

print('Testing model...')
test_loss, test_ace = test_model(homographynet, test_dataloader, homographynet_lossfn)

print(f'Test loss (MSE): {test_loss:.8f}')
print(f'Test corner error (MACE): {test_ace:.4f}')
# Out:
# Minimum training loss (MSE): 0.03385247
# Minimum validation loss (MSE): 0.02174733
#
# Testing model...
# Test loss (MSE): 0.02326978
# Test corner error (MACE): 5.5338

# %%
drive.flush_and_unmount()
