# %% [markdown]
# ## Mount GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Parameters

# %%
# Dataset
dataset_folder_path = '/content/gdrive/MyDrive/deephomography/dataset/'
rho = 32
patch_size = 128
image_size = (320,240)

# Dataloader
batch_size = 64
dataset_mean = 113.55

# Training
num_iterations = 90000
checkpoint_path = '/content/gdrive/MyDrive/deephomography/models/checkpoint.pth'

# Create required folder(s)
# !mkdir -p $(dirname {checkpoint_path})

# %% [markdown]
# ## Extract dataset

# %%
# !echo "Extracting train2017homography.tar..."
# !tar -xf {dataset_folder_path}/train2017homography.tar

# !echo "Extracting val2017homography.tar..."
# !tar -xf {dataset_folder_path}/val2017homography.tar

# !echo "Extracting test2017homography.tar..."
# !tar -xf {dataset_folder_path}/test2017homography.tar
# Out:
# Extracting train2017homography.tar...
# Extracting val2017homography.tar...
# Extracting test2017homography.tar...

# %% [markdown]
# ## Homography Estimation with Deep Neural Networks

# %% [markdown]
# ### Custom PyTorch dataset & dataloader

# %%
import os
import numpy as np
import torch

class HomographyDataset(torch.utils.data.Dataset):
    def __init__(self, folder_path):
        self.folder_path = folder_path

        # List folder contents
        self.file_list = os.listdir(self.folder_path)

        # Set dataset size
        self.size = len(self.file_list)
    
    def __len__(self):
        return self.size

    def __getitem__(self, index):
        # Load sample
        patch, perturbed_patch, patch_points, perturbation = np.load(os.path.join(self.folder_path, self.file_list[index]), allow_pickle=True)

        # Normalisation
        patch = patch.astype(np.float32) - dataset_mean
        perturbed_patch = perturbed_patch.astype(np.float32) - dataset_mean
        perturbation = perturbation.astype(np.float32) / rho

        # Convert to PyTorch object
        patch = torch.unsqueeze(torch.from_numpy(patch), dim=0)
        perturbed_patch = torch.unsqueeze(torch.from_numpy(perturbed_patch), dim=0)
        perturbation = torch.flatten(torch.from_numpy(perturbation))

        # Stack two patches into a single tensor
        patch_pair = torch.concat((patch, perturbed_patch), dim=0)

        return patch_pair, perturbation

# Datasets
train_dataset = HomographyDataset(folder_path='train2017homography')
validation_dataset = HomographyDataset(folder_path='val2017homography')
test_dataset = HomographyDataset(folder_path='test2017homography')

# Number of processors
num_proc = len(os.sched_getaffinity(0))

# Dataloaders
train_dataloader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_proc)
validation_dataloader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=batch_size, shuffle=True, num_workers=num_proc)
test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=num_proc)

# %% [markdown]
# ### Network definition

# %%
class HomographyNet(torch.nn.Module):
    def __init__(self):
        super().__init__() # don't remove this line
        
        self.conv1 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=2, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU())
                                    
        self.conv2 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2))
        
        self.conv3 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU())
        
        self.conv4 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2))
        
        self.conv5 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU()) 
              
        self.conv6 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2))
        
        self.conv7 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU())
        
        self.conv8 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same'),
            torch.nn.BatchNorm2d(num_features=128),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.5))
        
        self.fc1 = torch.nn.Sequential(
            torch.nn.Linear(in_features=128*16*16, out_features=1024),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.5))
        
        self.fc2 = torch.nn.Sequential(
            torch.nn.Linear(in_features=1024, out_features=8))

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.conv8(x)

        x = torch.flatten(x, 1)

        x = self.fc1(x)
        x = self.fc2(x)

        return x

homographynet = HomographyNet().to('cuda')

# %% [markdown]
# ### Test network shapes

# %%
import torchsummary

for dummy_input, dummy_label in train_dataloader:
    dummy_input, dummy_label = dummy_input.to('cuda'), dummy_label.to('cuda')

    dummy_output = homographynet(dummy_input)

    torchsummary.summary(homographynet, dummy_input.shape[1:])
    #print(homographynet)

    print(f'Dummy input shape: {dummy_input.shape}')
    print(f'Dummy label shape: {dummy_label.shape}')
    print(f'Dummy output shape: {dummy_output.shape}')
    print()

    if dummy_label.shape != dummy_output.shape:
        raise Exception("Shape mismatch for label and output!") 
    else:
        print("Label and output shapes are consistent.")

    break
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           1,216
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#             Conv2d-4         [-1, 64, 128, 128]          36,928
#        BatchNorm2d-5         [-1, 64, 128, 128]             128
#               ReLU-6         [-1, 64, 128, 128]               0
#          MaxPool2d-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,928
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#            Conv2d-11           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-12           [-1, 64, 64, 64]             128
#              ReLU-13           [-1, 64, 64, 64]               0
#         MaxPool2d-14           [-1, 64, 32, 32]               0
#            Conv2d-15          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-16          [-1, 128, 32, 32]             256
#              ReLU-17          [-1, 128, 32, 32]               0
#            Conv2d-18          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-19          [-1, 128, 32, 32]             256
#              ReLU-20          [-1, 128, 32, 32]               0
#         MaxPool2d-21          [-1, 128, 16, 16]               0
#            Conv2d-22          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#              ReLU-24          [-1, 128, 16, 16]               0
#            Conv2d-25          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-26          [-1, 128, 16, 16]             256
#              ReLU-27          [-1, 128, 16, 16]               0
#           Dropout-28          [-1, 128, 16, 16]               0
#            Linear-29                 [-1, 1024]      33,555,456
#              ReLU-30                 [-1, 1024]               0
#           Dropout-31                 [-1, 1024]               0
#            Linear-32                    [-1, 8]           8,200
# ================================================================
# Total params: 34,193,800
# Trainable params: 34,193,800
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 70.52
# Params size (MB): 130.44
# Estimated Total Size (MB): 201.09
# ----------------------------------------------------------------
# Dummy input shape: torch.Size([64, 2, 128, 128])
# Dummy label shape: torch.Size([64, 8])
# Dummy output shape: torch.Size([64, 8])
#
# Label and output shapes are consistent.

# %% [markdown]
# ### Optimizer and loss function

# %%
# Optimizer
homographynet_optim = torch.optim.SGD(homographynet.parameters(), lr=0.005, momentum=0.9)

# Loss function
homographynet_lossfn = torch.nn.MSELoss()

# %% [markdown]
# ### Validation/Test function

# %%
def average_corner_error(true, pred):
    true_scaled = rho * true.cpu().numpy()
    pred_scaled = rho * pred.cpu().numpy()

    squared_error = np.square(true_scaled - pred_scaled)

    batch_ace = (np.sqrt(squared_error[:,0] + squared_error[:,1]) + 
                 np.sqrt(squared_error[:,2] + squared_error[:,3]) + 
                 np.sqrt(squared_error[:,4] + squared_error[:,5]) + 
                 np.sqrt(squared_error[:,6] + squared_error[:,7])) / 4

    return np.mean(batch_ace, axis=0)

def test_model(model, dataloader, lossfn):
    # Set network to eval mode
    model.eval()

    # Initialise total loss and average corner error
    total_loss = 0
    total_ace = 0
    
    # Disable gradients inside this block
    with torch.no_grad():
        for patch_pair, H_fp in dataloader:
            # Move batch to GPU
            patch_pair, H_fp = patch_pair.cuda(), H_fp.cuda()

            # Run the network and obtain predicted homography 
            H_fp_pred = model(patch_pair)

            # Calculate loss
            total_loss += lossfn(H_fp, H_fp_pred)

            # Calculate average corner error
            total_ace += average_corner_error(H_fp, H_fp_pred)

    # Calculate mean loss
    mean_loss = total_loss / len(dataloader)

    # Calculate mean average corner error
    mean_ace = total_ace / len(dataloader)

    # Set network to train mode
    model.train()
    
    return mean_loss, mean_ace

# %% [markdown]
# ### Training

# %%
ep_start = 0
training_loss_list = []
validation_loss_list = []

# Calculate number of epochs
num_epochs = np.ceil(num_iterations / len(train_dataloader)).astype(int)

# Calculate number of reporting steps
num_report_steps = np.floor(len(train_dataloader) / 10)

# Calculate required digits for number of total epochs and iterations (for reporting)
epd = len(str(num_epochs))
itd = len(str(len(train_dataloader)))

# Check if a checkpoint exists
if os.path.isfile(checkpoint_path):
    # Load checkpoint
    print('Loading checkpoint...')
    checkpoint = torch.load(checkpoint_path)

    # Load variables from checkpoint
    ep_start = checkpoint['epoch']
    homographynet.load_state_dict(checkpoint['network_state'])
    homographynet_optim.load_state_dict(checkpoint['optim_state'])
    training_loss_list = checkpoint['tloss_list']
    validation_loss_list = checkpoint['vloss_list']

for ep in range(ep_start, num_epochs):
    # Initialise total loss
    total_loss = 0

    for it, (patch_pair, H_fp) in enumerate(train_dataloader):
        # Move batch to GPU
        patch_pair, H_fp = patch_pair.to("cuda"), H_fp.to("cuda")
        
        # Run the network and obtain predicted homography 
        H_fp_pred = homographynet(patch_pair)

        # Calculate loss
        loss = homographynet_lossfn(H_fp, H_fp_pred)
        total_loss += loss
        
        # Take an optimization step (clear the gradients first)
        homographynet_optim.zero_grad()
        loss.backward()
        homographynet_optim.step()
        
        if (it == 0 or (it + 1) % num_report_steps == 0):
            print(f'[Epoch: {(ep + 1):0{epd}d}/{num_epochs}, Iteration: {(it + 1):0{itd}d}/{len(train_dataloader)}] Iteration Loss (MSE): {loss:.6f}')
    
    # Calculate average training loss
    training_loss = total_loss / len(train_dataloader)
    training_loss_list.append(training_loss)

    # Try model on validation set and calculate 
    validation_loss, validation_ace = test_model(homographynet, validation_dataloader, homographynet_lossfn)
    validation_loss_list.append(validation_loss)

    print(f'[Epoch: {(ep + 1):0{epd}d}/{num_epochs}, Iteration: {(it + 1):0{itd}d}/{len(train_dataloader)}] Training Loss (MSE): {training_loss:.6f}, Validation Loss (MSE): {validation_loss:.6f}, Validation Corner Error (MACE): {validation_ace:.4f}')

    # Save checkpoint
    print('Saving checkpoint...')
    torch.save({'epoch': ep+1, 'network_state': homographynet.state_dict(), 'optim_state': homographynet_optim.state_dict(), 'tloss_list': training_loss_list, 'vloss_list': validation_loss_list}, checkpoint_path)
# Out:
# [Epoch: 01/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.443816
# [Epoch: 01/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.335079
# [Epoch: 01/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.304907
# [Epoch: 01/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.302996
# [Epoch: 01/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.274855
# [Epoch: 01/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.209584
# [Epoch: 01/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.181765
# [Epoch: 01/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.189442
# [Epoch: 01/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.173892
# [Epoch: 01/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.156741
# [Epoch: 01/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.167789
# [Epoch: 01/49, Iteration: 1849/1849] Training Loss (MSE): 0.236680, Validation Loss (MSE): 0.164845, Validation Corner Error (MACE): 15.9737
# Saving checkpoint...
# [Epoch: 02/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.144824
# [Epoch: 02/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.141453
# [Epoch: 02/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.142737
# [Epoch: 02/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.123955
# [Epoch: 02/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.123401
# [Epoch: 02/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.151781
# [Epoch: 02/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.112648
# [Epoch: 02/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.103998
# [Epoch: 02/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.124191
# [Epoch: 02/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.093362
# [Epoch: 02/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.101518
# [Epoch: 02/49, Iteration: 1849/1849] Training Loss (MSE): 0.126570, Validation Loss (MSE): 0.095853, Validation Corner Error (MACE): 12.0048
# Saving checkpoint...
# [Epoch: 03/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.104091
# [Epoch: 03/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.098753
# [Epoch: 03/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.107671
# [Epoch: 03/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.121131
# [Epoch: 03/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.097155
# [Epoch: 03/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.107452
# [Epoch: 03/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.095816
# [Epoch: 03/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.100405
# [Epoch: 03/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.109967
# [Epoch: 03/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.098308
# [Epoch: 03/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.090218
# [Epoch: 03/49, Iteration: 1849/1849] Training Loss (MSE): 0.098399, Validation Loss (MSE): 0.087190, Validation Corner Error (MACE): 11.3658
# Saving checkpoint...
# [Epoch: 04/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.092668
# [Epoch: 04/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.092589
# [Epoch: 04/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.088371
# [Epoch: 04/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.082435
# [Epoch: 04/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.091028
# [Epoch: 04/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.084570
# [Epoch: 04/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.107905
# [Epoch: 04/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.074870
# [Epoch: 04/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.076101
# [Epoch: 04/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.064432
# [Epoch: 04/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.066076
# [Epoch: 04/49, Iteration: 1849/1849] Training Loss (MSE): 0.085898, Validation Loss (MSE): 0.068470, Validation Corner Error (MACE): 10.0394
# Saving checkpoint...
# [Epoch: 05/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.079935
# [Epoch: 05/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.078863
# [Epoch: 05/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.077551
# [Epoch: 05/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.076080
# [Epoch: 05/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.077935
# [Epoch: 05/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.074373
# [Epoch: 05/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.092993
# [Epoch: 05/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.068346
# [Epoch: 05/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.062487
# [Epoch: 05/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.069461
# [Epoch: 05/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.083271
# [Epoch: 05/49, Iteration: 1849/1849] Training Loss (MSE): 0.077574, Validation Loss (MSE): 0.060906, Validation Corner Error (MACE): 9.3595
# Saving checkpoint...
# [Epoch: 06/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.072611
# [Epoch: 06/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.063802
# [Epoch: 06/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.076343
# [Epoch: 06/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.078181
# [Epoch: 06/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.066942
# [Epoch: 06/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.067833
# [Epoch: 06/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.066385
# [Epoch: 06/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.081275
# [Epoch: 06/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.060512
# [Epoch: 06/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.067020
# [Epoch: 06/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.072505
# [Epoch: 06/49, Iteration: 1849/1849] Training Loss (MSE): 0.072195, Validation Loss (MSE): 0.077318, Validation Corner Error (MACE): 10.6096
# Saving checkpoint...
# [Epoch: 07/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.060321
# [Epoch: 07/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.064408
# [Epoch: 07/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.059961
# [Epoch: 07/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.066677
# [Epoch: 07/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.070946
# [Epoch: 07/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.081693
# [Epoch: 07/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.059017
# [Epoch: 07/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.056825
# [Epoch: 07/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.079203
# [Epoch: 07/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.085826
# [Epoch: 07/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.055204
# [Epoch: 07/49, Iteration: 1849/1849] Training Loss (MSE): 0.067954, Validation Loss (MSE): 0.047710, Validation Corner Error (MACE): 8.2121
# Saving checkpoint...
# [Epoch: 08/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.070170
# [Epoch: 08/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.054751
# [Epoch: 08/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.057522
# [Epoch: 08/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.060238
# [Epoch: 08/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.055808
# [Epoch: 08/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.065393
# [Epoch: 08/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.063265
# [Epoch: 08/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.088490
# [Epoch: 08/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.060340
# [Epoch: 08/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.071407
# [Epoch: 08/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.072290
# [Epoch: 08/49, Iteration: 1849/1849] Training Loss (MSE): 0.064490, Validation Loss (MSE): 0.052830, Validation Corner Error (MACE): 8.6033
# Saving checkpoint...
# [Epoch: 09/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.061397
# [Epoch: 09/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.068777
# [Epoch: 09/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.058897
# [Epoch: 09/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.064728
# [Epoch: 09/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.064517
# [Epoch: 09/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.049402
# [Epoch: 09/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.063205
# [Epoch: 09/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.052536
# [Epoch: 09/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.054081
# [Epoch: 09/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.065920
# [Epoch: 09/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.059117
# [Epoch: 09/49, Iteration: 1849/1849] Training Loss (MSE): 0.061638, Validation Loss (MSE): 0.057942, Validation Corner Error (MACE): 9.1765
# Saving checkpoint...
# [Epoch: 10/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.053595
# [Epoch: 10/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.049400
# [Epoch: 10/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.054987
# [Epoch: 10/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.063627
# [Epoch: 10/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.059331
# [Epoch: 10/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.061205
# [Epoch: 10/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.070208
# [Epoch: 10/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.062637
# [Epoch: 10/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.060695
# [Epoch: 10/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.067290
# [Epoch: 10/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.067731
# [Epoch: 10/49, Iteration: 1849/1849] Training Loss (MSE): 0.059032, Validation Loss (MSE): 0.042871, Validation Corner Error (MACE): 7.7630
# Saving checkpoint...
# [Epoch: 11/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.070598
# [Epoch: 11/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.053119
# [Epoch: 11/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.052119
# [Epoch: 11/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.045677
# [Epoch: 11/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.051292
# [Epoch: 11/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.050843
# [Epoch: 11/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.054980
# [Epoch: 11/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.070656
# [Epoch: 11/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.049788
# [Epoch: 11/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.055668
# [Epoch: 11/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.062197
# [Epoch: 11/49, Iteration: 1849/1849] Training Loss (MSE): 0.056691, Validation Loss (MSE): 0.044568, Validation Corner Error (MACE): 7.8562
# Saving checkpoint...
# [Epoch: 12/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.055469
# [Epoch: 12/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.059096
# [Epoch: 12/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.045749
# [Epoch: 12/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.052008
# [Epoch: 12/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.049174
# [Epoch: 12/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.061247
# [Epoch: 12/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.055363
# [Epoch: 12/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.055545
# [Epoch: 12/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.049773
# [Epoch: 12/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.056580
# [Epoch: 12/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.059936
# [Epoch: 12/49, Iteration: 1849/1849] Training Loss (MSE): 0.054956, Validation Loss (MSE): 0.042592, Validation Corner Error (MACE): 7.6954
# Saving checkpoint...
# [Epoch: 13/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.054748
# [Epoch: 13/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.040423
# [Epoch: 13/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.059074
# [Epoch: 13/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.051871
# [Epoch: 13/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.051316
# [Epoch: 13/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.046420
# [Epoch: 13/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.059462
# [Epoch: 13/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.052042
# [Epoch: 13/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.050447
# [Epoch: 13/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.047771
# [Epoch: 13/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.054608
# [Epoch: 13/49, Iteration: 1849/1849] Training Loss (MSE): 0.053124, Validation Loss (MSE): 0.041664, Validation Corner Error (MACE): 7.5695
# Saving checkpoint...
# [Epoch: 14/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.051129
# [Epoch: 14/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.064609
# [Epoch: 14/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.047126
# [Epoch: 14/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.051595
# [Epoch: 14/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.054443
# [Epoch: 14/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.054207
# [Epoch: 14/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.050224
# [Epoch: 14/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.050561
# [Epoch: 14/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.053036
# [Epoch: 14/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.055971
# [Epoch: 14/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.053426
# [Epoch: 14/49, Iteration: 1849/1849] Training Loss (MSE): 0.051809, Validation Loss (MSE): 0.045126, Validation Corner Error (MACE): 7.8953
# Saving checkpoint...
# [Epoch: 15/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.054376
# [Epoch: 15/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.052948
# [Epoch: 15/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.050467
# [Epoch: 15/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.051150
# [Epoch: 15/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.049806
# [Epoch: 15/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.048977
# [Epoch: 15/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.059690
# [Epoch: 15/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.044916
# [Epoch: 15/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.056036
# [Epoch: 15/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.048112
# [Epoch: 15/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.038976
# [Epoch: 15/49, Iteration: 1849/1849] Training Loss (MSE): 0.050300, Validation Loss (MSE): 0.041524, Validation Corner Error (MACE): 7.5571
# Saving checkpoint...
# [Epoch: 16/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.051815
# [Epoch: 16/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.053886
# [Epoch: 16/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.049115
# [Epoch: 16/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.045208
# [Epoch: 16/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.050605
# [Epoch: 16/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.044305
# [Epoch: 16/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.043418
# [Epoch: 16/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.040212
# [Epoch: 16/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.047812
# [Epoch: 16/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.048836
# [Epoch: 16/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.048545
# [Epoch: 16/49, Iteration: 1849/1849] Training Loss (MSE): 0.048789, Validation Loss (MSE): 0.044576, Validation Corner Error (MACE): 7.7449
# Saving checkpoint...
# [Epoch: 17/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.041929
# [Epoch: 17/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.046197
# [Epoch: 17/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.047178
# [Epoch: 17/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.043370
# [Epoch: 17/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.055906
# [Epoch: 17/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.051928
# [Epoch: 17/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.040067
# [Epoch: 17/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.047366
# [Epoch: 17/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.049016
# [Epoch: 17/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.045932
# [Epoch: 17/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.048680
# [Epoch: 17/49, Iteration: 1849/1849] Training Loss (MSE): 0.047708, Validation Loss (MSE): 0.043086, Validation Corner Error (MACE): 7.6961
# Saving checkpoint...
# [Epoch: 18/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.046763
# [Epoch: 18/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.046293
# [Epoch: 18/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.050115
# [Epoch: 18/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.045641
# [Epoch: 18/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.043409
# [Epoch: 18/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.039044
# [Epoch: 18/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.043666
# [Epoch: 18/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.043499
# [Epoch: 18/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.044744
# [Epoch: 18/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.051214
# [Epoch: 18/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.046893
# [Epoch: 18/49, Iteration: 1849/1849] Training Loss (MSE): 0.046647, Validation Loss (MSE): 0.044416, Validation Corner Error (MACE): 7.8461
# Saving checkpoint...
# [Epoch: 19/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.043642
# [Epoch: 19/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.050208
# [Epoch: 19/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.041437
# [Epoch: 19/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.043967
# [Epoch: 19/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.050179
# [Epoch: 19/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.047464
# [Epoch: 19/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.039911
# [Epoch: 19/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.050935
# [Epoch: 19/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.054950
# [Epoch: 19/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.042820
# [Epoch: 19/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.046236
# [Epoch: 19/49, Iteration: 1849/1849] Training Loss (MSE): 0.045654, Validation Loss (MSE): 0.044622, Validation Corner Error (MACE): 7.9205
# Saving checkpoint...
# [Epoch: 20/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.048643
# [Epoch: 20/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.044171
# [Epoch: 20/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.047945
# [Epoch: 20/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.052203
# [Epoch: 20/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.043281
# [Epoch: 20/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.047082
# [Epoch: 20/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.052962
# [Epoch: 20/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.043968
# [Epoch: 20/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.048314
# [Epoch: 20/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.047563
# [Epoch: 20/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.049272
# [Epoch: 20/49, Iteration: 1849/1849] Training Loss (MSE): 0.044715, Validation Loss (MSE): 0.034435, Validation Corner Error (MACE): 6.8765
# Saving checkpoint...
# [Epoch: 21/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.038930
# [Epoch: 21/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.041600
# [Epoch: 21/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.042313
# [Epoch: 21/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.044676
# [Epoch: 21/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.046533
# [Epoch: 21/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.046818
# [Epoch: 21/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.039804
# [Epoch: 21/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.047501
# [Epoch: 21/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.049502
# [Epoch: 21/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.039313
# [Epoch: 21/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.039070
# [Epoch: 21/49, Iteration: 1849/1849] Training Loss (MSE): 0.043996, Validation Loss (MSE): 0.031683, Validation Corner Error (MACE): 6.5862
# Saving checkpoint...
# [Epoch: 22/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.048369
# [Epoch: 22/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.042241
# [Epoch: 22/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.045213
# [Epoch: 22/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.040365
# [Epoch: 22/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.044691
# [Epoch: 22/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.038804
# [Epoch: 22/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.042577
# [Epoch: 22/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.040773
# [Epoch: 22/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.051927
# [Epoch: 22/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.034137
# [Epoch: 22/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.041084
# [Epoch: 22/49, Iteration: 1849/1849] Training Loss (MSE): 0.042971, Validation Loss (MSE): 0.037163, Validation Corner Error (MACE): 7.1694
# Saving checkpoint...
# [Epoch: 23/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.049510
# [Epoch: 23/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.040757
# [Epoch: 23/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.046094
# [Epoch: 23/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.039012
# [Epoch: 23/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.037461
# [Epoch: 23/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.046421
# [Epoch: 23/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.043973
# [Epoch: 23/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.042517
# [Epoch: 23/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.056766
# [Epoch: 23/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.040398
# [Epoch: 23/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.034759
# [Epoch: 23/49, Iteration: 1849/1849] Training Loss (MSE): 0.042126, Validation Loss (MSE): 0.037082, Validation Corner Error (MACE): 7.1901
# Saving checkpoint...
# [Epoch: 24/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.050253
# [Epoch: 24/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.044722
# [Epoch: 24/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.040058
# [Epoch: 24/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.038373
# [Epoch: 24/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.042116
# [Epoch: 24/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.041983
# [Epoch: 24/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.044096
# [Epoch: 24/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.042724
# [Epoch: 24/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.047238
# [Epoch: 24/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.042597
# [Epoch: 24/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.038350
# [Epoch: 24/49, Iteration: 1849/1849] Training Loss (MSE): 0.041434, Validation Loss (MSE): 0.038084, Validation Corner Error (MACE): 7.3931
# Saving checkpoint...
# [Epoch: 25/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.044977
# [Epoch: 25/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.050525
# [Epoch: 25/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.036549
# [Epoch: 25/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.037638
# [Epoch: 25/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.042786
# [Epoch: 25/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.040189
# [Epoch: 25/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.041885
# [Epoch: 25/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.044725
# [Epoch: 25/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.035511
# [Epoch: 25/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.047547
# [Epoch: 25/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.042769
# [Epoch: 25/49, Iteration: 1849/1849] Training Loss (MSE): 0.040777, Validation Loss (MSE): 0.031101, Validation Corner Error (MACE): 6.5498
# Saving checkpoint...
# [Epoch: 26/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.037707
# [Epoch: 26/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.048614
# [Epoch: 26/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.041286
# [Epoch: 26/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.039771
# [Epoch: 26/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.040000
# [Epoch: 26/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.035329
# [Epoch: 26/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.038799
# [Epoch: 26/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.038570
# [Epoch: 26/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.042293
# [Epoch: 26/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.037188
# [Epoch: 26/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.041610
# [Epoch: 26/49, Iteration: 1849/1849] Training Loss (MSE): 0.040113, Validation Loss (MSE): 0.029548, Validation Corner Error (MACE): 6.3577
# Saving checkpoint...
# [Epoch: 27/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.036523
# [Epoch: 27/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.040530
# [Epoch: 27/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.040578
# [Epoch: 27/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.042928
# [Epoch: 27/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.046344
# [Epoch: 27/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.045752
# [Epoch: 27/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.037102
# [Epoch: 27/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.037592
# [Epoch: 27/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.035152
# [Epoch: 27/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.042400
# [Epoch: 27/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.037248
# [Epoch: 27/49, Iteration: 1849/1849] Training Loss (MSE): 0.039324, Validation Loss (MSE): 0.031549, Validation Corner Error (MACE): 6.5696
# Saving checkpoint...
# [Epoch: 28/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.034709
# [Epoch: 28/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.036701
# [Epoch: 28/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.051158
# [Epoch: 28/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.042976
# [Epoch: 28/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.031251
# [Epoch: 28/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.039272
# [Epoch: 28/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.036379
# [Epoch: 28/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.043575
# [Epoch: 28/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.044714
# [Epoch: 28/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.037847
# [Epoch: 28/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.042888
# [Epoch: 28/49, Iteration: 1849/1849] Training Loss (MSE): 0.038700, Validation Loss (MSE): 0.029406, Validation Corner Error (MACE): 6.4180
# Saving checkpoint...
# [Epoch: 29/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.035664
# [Epoch: 29/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.033369
# [Epoch: 29/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.038713
# [Epoch: 29/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.039547
# [Epoch: 29/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.039295
# [Epoch: 29/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.037924
# [Epoch: 29/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.041607
# [Epoch: 29/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.041768
# [Epoch: 29/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.037017
# [Epoch: 29/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.044741
# [Epoch: 29/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.034419
# [Epoch: 29/49, Iteration: 1849/1849] Training Loss (MSE): 0.037949, Validation Loss (MSE): 0.034365, Validation Corner Error (MACE): 6.8992
# Saving checkpoint...
# [Epoch: 30/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.041848
# [Epoch: 30/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.033634
# [Epoch: 30/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.036053
# [Epoch: 30/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.036122
# [Epoch: 30/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.038684
# [Epoch: 30/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.034381
# [Epoch: 30/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.033909
# [Epoch: 30/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.034534
# [Epoch: 30/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.041320
# [Epoch: 30/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.035600
# [Epoch: 30/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.034219
# [Epoch: 30/49, Iteration: 1849/1849] Training Loss (MSE): 0.037501, Validation Loss (MSE): 0.028676, Validation Corner Error (MACE): 6.2779
# Saving checkpoint...
# [Epoch: 31/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.035162
# [Epoch: 31/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.037085
# [Epoch: 31/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.037038
# [Epoch: 31/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.034437
# [Epoch: 31/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.035936
# [Epoch: 31/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.035955
# [Epoch: 31/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.040602
# [Epoch: 31/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.039187
# [Epoch: 31/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.036655
# [Epoch: 31/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.039828
# [Epoch: 31/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.029116
# [Epoch: 31/49, Iteration: 1849/1849] Training Loss (MSE): 0.036935, Validation Loss (MSE): 0.030212, Validation Corner Error (MACE): 6.4289
# Saving checkpoint...
# [Epoch: 32/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.035897
# [Epoch: 32/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.038967
# [Epoch: 32/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.034315
# [Epoch: 32/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.034535
# [Epoch: 32/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.035180
# [Epoch: 32/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.036040
# [Epoch: 32/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.035177
# [Epoch: 32/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.038692
# [Epoch: 32/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.040425
# [Epoch: 32/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.034286
# [Epoch: 32/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.034794
# [Epoch: 32/49, Iteration: 1849/1849] Training Loss (MSE): 0.036570, Validation Loss (MSE): 0.024661, Validation Corner Error (MACE): 5.7747
# Saving checkpoint...
# [Epoch: 33/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.037703
# [Epoch: 33/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.031737
# [Epoch: 33/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.033725
# [Epoch: 33/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.032989
# [Epoch: 33/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.032603
# [Epoch: 33/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.035966
# [Epoch: 33/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.037109
# [Epoch: 33/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.030420
# [Epoch: 33/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.034602
# [Epoch: 33/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.031813
# [Epoch: 33/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.040794
# [Epoch: 33/49, Iteration: 1849/1849] Training Loss (MSE): 0.036081, Validation Loss (MSE): 0.028421, Validation Corner Error (MACE): 6.2301
# Saving checkpoint...
# [Epoch: 34/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.032003
# [Epoch: 34/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.032861
# [Epoch: 34/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.036351
# [Epoch: 34/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.036832
# [Epoch: 34/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.034577
# [Epoch: 34/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.029897
# [Epoch: 34/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.033531
# [Epoch: 34/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.036810
# [Epoch: 34/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.034393
# [Epoch: 34/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.038322
# [Epoch: 34/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.036985
# [Epoch: 34/49, Iteration: 1849/1849] Training Loss (MSE): 0.035664, Validation Loss (MSE): 0.036228, Validation Corner Error (MACE): 7.2224
# Saving checkpoint...
# [Epoch: 35/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.035364
# [Epoch: 35/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.034815
# [Epoch: 35/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.036000
# [Epoch: 35/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.025333
# [Epoch: 35/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.033375
# [Epoch: 35/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.037286
# [Epoch: 35/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.037558
# [Epoch: 35/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.039274
# [Epoch: 35/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.032586
# [Epoch: 35/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.029919
# [Epoch: 35/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.035277
# [Epoch: 35/49, Iteration: 1849/1849] Training Loss (MSE): 0.035258, Validation Loss (MSE): 0.028576, Validation Corner Error (MACE): 6.2455
# Saving checkpoint...
# [Epoch: 36/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.034740
# [Epoch: 36/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.031291
# [Epoch: 36/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.030988
# [Epoch: 36/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.041652
# [Epoch: 36/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.040819
# [Epoch: 36/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.038719
# [Epoch: 36/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.031401
# [Epoch: 36/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.032785
# [Epoch: 36/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.029943
# [Epoch: 36/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.026671
# [Epoch: 36/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.041733
# [Epoch: 36/49, Iteration: 1849/1849] Training Loss (MSE): 0.034624, Validation Loss (MSE): 0.029890, Validation Corner Error (MACE): 6.4559
# Saving checkpoint...
# [Epoch: 37/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.033136
# [Epoch: 37/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.028051
# [Epoch: 37/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.029828
# [Epoch: 37/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.035599
# [Epoch: 37/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.031107
# [Epoch: 37/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.034314
# [Epoch: 37/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.036349
# [Epoch: 37/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.033332
# [Epoch: 37/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.041958
# [Epoch: 37/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.031109
# [Epoch: 37/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.039952
# [Epoch: 37/49, Iteration: 1849/1849] Training Loss (MSE): 0.034327, Validation Loss (MSE): 0.025016, Validation Corner Error (MACE): 5.8209
# Saving checkpoint...
# [Epoch: 38/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.033846
# [Epoch: 38/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.037674
# [Epoch: 38/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.034796
# [Epoch: 38/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.038716
# [Epoch: 38/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.034346
# [Epoch: 38/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.040163
# [Epoch: 38/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.040327
# [Epoch: 38/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.030023
# [Epoch: 38/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.037747
# [Epoch: 38/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.034912
# [Epoch: 38/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.034228
# [Epoch: 38/49, Iteration: 1849/1849] Training Loss (MSE): 0.034113, Validation Loss (MSE): 0.024227, Validation Corner Error (MACE): 5.7213
# Saving checkpoint...
# [Epoch: 39/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.035873
# [Epoch: 39/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.034931
# [Epoch: 39/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.032974
# [Epoch: 39/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.034773
# [Epoch: 39/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.029766
# [Epoch: 39/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.032881
# [Epoch: 39/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.030067
# [Epoch: 39/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.038200
# [Epoch: 39/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.030537
# [Epoch: 39/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.029044
# [Epoch: 39/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.025461
# [Epoch: 39/49, Iteration: 1849/1849] Training Loss (MSE): 0.033459, Validation Loss (MSE): 0.023748, Validation Corner Error (MACE): 5.6334
# Saving checkpoint...
# [Epoch: 40/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.029990
# [Epoch: 40/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.029655
# [Epoch: 40/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.031682
# [Epoch: 40/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.037388
# [Epoch: 40/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.030283
# [Epoch: 40/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.027697
# [Epoch: 40/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.031948
# [Epoch: 40/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.031273
# [Epoch: 40/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.034912
# [Epoch: 40/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.031922
# [Epoch: 40/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.041035
# [Epoch: 40/49, Iteration: 1849/1849] Training Loss (MSE): 0.033051, Validation Loss (MSE): 0.026564, Validation Corner Error (MACE): 5.9514
# Saving checkpoint...
# [Epoch: 41/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.028300
# [Epoch: 41/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.031022
# [Epoch: 41/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.037916
# [Epoch: 41/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.030779
# [Epoch: 41/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.033858
# [Epoch: 41/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.032780
# [Epoch: 41/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.027951
# [Epoch: 41/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.029071
# [Epoch: 41/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.034006
# [Epoch: 41/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.030233
# [Epoch: 41/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.037423
# [Epoch: 41/49, Iteration: 1849/1849] Training Loss (MSE): 0.032832, Validation Loss (MSE): 0.028765, Validation Corner Error (MACE): 6.2450
# Saving checkpoint...
# [Epoch: 42/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.040151
# [Epoch: 42/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.031319
# [Epoch: 42/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.035362
# [Epoch: 42/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.033777
# [Epoch: 42/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.030408
# [Epoch: 42/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.032459
# [Epoch: 42/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.043154
# [Epoch: 42/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.034600
# [Epoch: 42/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.032187
# [Epoch: 42/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.030618
# [Epoch: 42/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.029768
# [Epoch: 42/49, Iteration: 1849/1849] Training Loss (MSE): 0.032491, Validation Loss (MSE): 0.026387, Validation Corner Error (MACE): 5.9989
# Saving checkpoint...
# [Epoch: 43/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.027638
# [Epoch: 43/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.034466
# [Epoch: 43/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.030405
# [Epoch: 43/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.028783
# [Epoch: 43/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.032349
# [Epoch: 43/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.028660
# [Epoch: 43/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.031425
# [Epoch: 43/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.041313
# [Epoch: 43/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.026986
# [Epoch: 43/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.028402
# [Epoch: 43/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.032105
# [Epoch: 43/49, Iteration: 1849/1849] Training Loss (MSE): 0.031970, Validation Loss (MSE): 0.026784, Validation Corner Error (MACE): 6.0522
# Saving checkpoint...
# [Epoch: 44/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.032632
# [Epoch: 44/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.034655
# [Epoch: 44/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.031996
# [Epoch: 44/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.029696
# [Epoch: 44/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.029413
# [Epoch: 44/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.031123
# [Epoch: 44/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.039409
# [Epoch: 44/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.025478
# [Epoch: 44/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.026614
# [Epoch: 44/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.033578
# [Epoch: 44/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.029442
# [Epoch: 44/49, Iteration: 1849/1849] Training Loss (MSE): 0.031807, Validation Loss (MSE): 0.030041, Validation Corner Error (MACE): 6.3863
# Saving checkpoint...
# [Epoch: 45/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.026668
# [Epoch: 45/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.032121
# [Epoch: 45/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.029546
# [Epoch: 45/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.035488
# [Epoch: 45/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.033267
# [Epoch: 45/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.030922
# [Epoch: 45/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.032573
# [Epoch: 45/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.033465
# [Epoch: 45/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.027583
# [Epoch: 45/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.028647
# [Epoch: 45/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.028351
# [Epoch: 45/49, Iteration: 1849/1849] Training Loss (MSE): 0.031479, Validation Loss (MSE): 0.029608, Validation Corner Error (MACE): 6.4603
# Saving checkpoint...
# [Epoch: 46/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.031126
# [Epoch: 46/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.030280
# [Epoch: 46/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.034386
# [Epoch: 46/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.034302
# [Epoch: 46/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.035210
# [Epoch: 46/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.030650
# [Epoch: 46/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.032891
# [Epoch: 46/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.038605
# [Epoch: 46/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.029059
# [Epoch: 46/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.030980
# [Epoch: 46/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.040735
# [Epoch: 46/49, Iteration: 1849/1849] Training Loss (MSE): 0.031064, Validation Loss (MSE): 0.025321, Validation Corner Error (MACE): 5.8558
# Saving checkpoint...
# [Epoch: 47/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.030049
# [Epoch: 47/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.029220
# [Epoch: 47/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.025953
# [Epoch: 47/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.027777
# [Epoch: 47/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.026616
# [Epoch: 47/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.032660
# [Epoch: 47/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.030414
# [Epoch: 47/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.029976
# [Epoch: 47/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.028150
# [Epoch: 47/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.031959
# [Epoch: 47/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.031370
# [Epoch: 47/49, Iteration: 1849/1849] Training Loss (MSE): 0.030780, Validation Loss (MSE): 0.024380, Validation Corner Error (MACE): 5.7301
# Saving checkpoint...
# [Epoch: 48/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.026692
# [Epoch: 48/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.028419
# [Epoch: 48/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.027901
# [Epoch: 48/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.029060
# [Epoch: 48/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.027691
# [Epoch: 48/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.027541
# [Epoch: 48/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.034283
# [Epoch: 48/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.033564
# [Epoch: 48/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.026243
# [Epoch: 48/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.028076
# [Epoch: 48/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.042407
# [Epoch: 48/49, Iteration: 1849/1849] Training Loss (MSE): 0.030485, Validation Loss (MSE): 0.024826, Validation Corner Error (MACE): 5.8479
# Saving checkpoint...
# [Epoch: 49/49, Iteration: 0001/1849] Iteration Loss (MSE): 0.028318
# [Epoch: 49/49, Iteration: 0184/1849] Iteration Loss (MSE): 0.026139
# [Epoch: 49/49, Iteration: 0368/1849] Iteration Loss (MSE): 0.028856
# [Epoch: 49/49, Iteration: 0552/1849] Iteration Loss (MSE): 0.033964
# [Epoch: 49/49, Iteration: 0736/1849] Iteration Loss (MSE): 0.027866
# [Epoch: 49/49, Iteration: 0920/1849] Iteration Loss (MSE): 0.033318
# [Epoch: 49/49, Iteration: 1104/1849] Iteration Loss (MSE): 0.026774
# [Epoch: 49/49, Iteration: 1288/1849] Iteration Loss (MSE): 0.029569
# [Epoch: 49/49, Iteration: 1472/1849] Iteration Loss (MSE): 0.030566
# [Epoch: 49/49, Iteration: 1656/1849] Iteration Loss (MSE): 0.028970
# [Epoch: 49/49, Iteration: 1840/1849] Iteration Loss (MSE): 0.034737
# [Epoch: 49/49, Iteration: 1849/1849] Training Loss (MSE): 0.030202, Validation Loss (MSE): 0.023892, Validation Corner Error (MACE): 5.6126
# Saving checkpoint...

# %% [markdown]
# ### Testing

# %%
import matplotlib.pyplot as plt

# Load checkpoint from file
checkpoint = torch.load(checkpoint_path)

# Load variables from checkpoint
ep_start = checkpoint['epoch']
homographynet.load_state_dict(checkpoint['network_state'])
training_loss_list_cuda = checkpoint['tloss_list']
validation_loss_list_cuda = checkpoint['vloss_list']

# Move losses to CPU and convert to Numpy
training_loss_list = [i.cpu().detach().numpy() for i in training_loss_list_cuda]
validation_loss_list = [i.cpu().detach().numpy() for i in validation_loss_list_cuda]

# Plot learning curve
plt.figure()
plt.title('Training & Validation Losses')
plt.xlabel('epoch')
plt.ylabel('mse')
plt.plot(training_loss_list, 'b', validation_loss_list, 'r')
plt.legend(['training','validation'])
plt.show()

# Print minimum training and validation losses
print()
print(f'Minimum training loss (MSE): {min(training_loss_list):.8f}')
print(f'Minimum validation loss (MSE): {min(validation_loss_list):.8f}')
print()

print('Testing model...')
test_loss, test_ace = test_model(homographynet, test_dataloader, homographynet_lossfn)

print(f'Test loss (MSE): {test_loss:.8f}')
print(f'Test corner error (MACE): {test_ace:.4f}')
# Out:
# Minimum training loss (MSE): 0.03020170
# Minimum validation loss (MSE): 0.02374827
#
# Testing model...
# Test loss (MSE): 0.02408394
# Test corner error (MACE): 5.6361

# %%
drive.flush_and_unmount()
